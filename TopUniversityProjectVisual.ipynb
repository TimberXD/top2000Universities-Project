# %% [raw]
# import numpy as np
# import pandas as pd
# from matplotlib import pyplot as plt
#
# topunivers = pd.read_csv("topuniversities.csv", encoding=('ISO-8859-1'))
# topunivers

# %% [markdown]
# # Top 8 talik Universitetlarda alumni employment darajalari

# %%
dataset_univ = topunivers.sort_values(by=['world_rank'],ascending=True)
sakkiz_univ = dataset_univ.head(8)

sorted_dataset = sakkiz_univ.sort_values(by=["alumni_employment"],ascending=True)
sorted_dataset

sorted_alumni = sorted_dataset["alumni_employment"]
sorted_alumni

sorted_nomi = sorted_dataset['institution']
sorted_nomi


plt.scatter(sorted_alumni, sorted_nomi)
plt.title("Top 8 talik Universitetlarda alumni employment darajalari")
plt.xlabel("Alumni employment bo'yicha o'rni")
plt.ylabel("Universitet nomlari")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
dataset_univ = topunivers.sort_values(by=['world_rank'],ascending=True)
sakkiz_univ = dataset_univ.head(8)
sakkiz_univ

sakkiz_alumni = sakkiz_univ["alumni_employment"]
sakkiz_alumni

sakkiz_nomi = sakkiz_univ['institution']
sakkiz_nomi

plt.scatter(sakkiz_alumni, sakkiz_nomi)
plt.title("Top 8 talik Universitetlarda alumni employment darajalari")
plt.xlabel("Alumni employment bo'yicha o'rni")
plt.ylabel("Universitet nomlari")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Yangi mavzu

# %%
import plotly.express as px
import plotly.graph_objects as go


amerika_univ = topunivers.groupby(['country']).get_group("USA")
firstamerika_grouped = amerika_univ.head(5)
secondamerika_grouped = amerika_univ.tail(5)
fullamerika = firstamerika_grouped + secondamerika_grouped

fullinfo = fullamerika.score
fullinfo
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 5      NaN
# 6      NaN
# 1980   NaN
# 1988   NaN
# 1989   NaN
# 1990   NaN
# 1992   NaN
# Name: score, dtype: float64

# %%
univ_nametion = amerika_grouped.institution
univ_score = amerika_grouped.score

plt.plot(univ_nametion,univ_score)
